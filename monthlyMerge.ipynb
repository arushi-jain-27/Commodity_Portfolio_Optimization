# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('predictors.xlsx')

# %%
df['date'] = df['date'].dt.to_period('M')

# %%
df.head()
# Out:
#       date  CPURNSA Index  RR2YCUS Index  EHGDUSY Index   INDPRO      M1  \
# 0  2001-01            NaN            NaN            NaN  92.0304  1096.7
# 1  2001-01            NaN            NaN            NaN      NaN     NaN
# 2  2001-01            NaN            NaN            NaN      NaN     NaN
# 3  2001-01            NaN            NaN            NaN      NaN     NaN
# 4  2001-01            NaN            NaN            NaN      NaN     NaN
#
#        M2  Bill Rate 13 week  Unemployment Rate       ERP  ...  \
# 0  4975.7                NaN                4.2  0.716832  ...
# 1     NaN                NaN                NaN       NaN  ...
# 2     NaN                NaN                NaN       NaN  ...
# 3     NaN                NaN                NaN       NaN  ...
# 4     NaN                NaN                NaN       NaN  ...
#
#    European Union        Mexico         Japan   Korea, Rep.       Germany  \
# ...

# %%
df_new = df.groupby(['date'], as_index=False).mean() # Take mean for each month

# %%
df_new = df_new.set_index('date')

# %%
df_new = df_new.interpolate(method ='linear', limit_direction ='forward') # Interpolate NaN

# %%
df_new.to_excel('predictors_monthly.xlsx')
